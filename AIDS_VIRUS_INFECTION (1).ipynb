# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv("/content/AIDS_Classification.csv")
df = pd.read_csv("/content/AIDS_Classification_15000.csv")
#df = pd.read_csv("/content/AIDS_Classification_5000.csv")
#df = pd.read_csv("/content/AIDS_Classification_50000.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time      15000 non-null  int64
#  1   trt       15000 non-null  int64
#  2   age       15000 non-null  int64
#  3   wtkg      15000 non-null  float64
#  4   hemo      15000 non-null  int64
#  5   homo      15000 non-null  int64
#  6   drugs     15000 non-null  int64
#  7   karnof    15000 non-null  int64
#  8   oprior    15000 non-null  int64
#  9   z30       15000 non-null  int64
#  10  preanti   15000 non-null  int64
#  11  race      15000 non-null  int64
#  12  gender    15000 non-null  int64
#  13  str2      15000 non-null  int64
#  14  strat     15000 non-null  int64
#  15  symptom   15000 non-null  int64
#  16  treat     15000 non-null  int64
#  17  offtrt    15000 non-null  int64
#  18  cd40      15000 non-null  int64
#  19  cd420     15000 non-null  int64
#  20  cd80      15000 non-null  int64
#  21  cd820     15000 non-null  int64
#  22  infected  15000 non-null  int64
# dtypes: float64(1), int64(22)
# memory usage: 2.6 MB

# %%
df.head()
# Out:
#    time  trt  age      wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  \
# 0  1108    1   37  88.11364     0     1      1     100       0    1  ...
# 1  1079    0   43  66.77075     0     0      0     100       0    1  ...
# 2   492    1   34  82.91725     0     0      0      90       0    1  ...
# 3  1191    1   41  98.91817     0     0      0      81       0    1  ...
# 4  1141    3   47  53.61717     0     1      0     100       0    0  ...
#
#    str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  cd820  infected
# 0     1      1        0      0       0   389    320   734    737         1
# 1     0      2        0      1       1   318    432   912   1213         0
# 2     1      2        0      1       1   326    524   660    835         0
# 3     1      3        0      1       0   318    232  1131    982         1
# 4     0      1        0      1       0   280    337   515    679         0
#
# [5 rows x 23 columns]

# %%
df.head(30)
# Out:
#     time  trt  age       wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  \
# 0   1108    1   37   88.11364     0     1      1     100       0    1  ...
# 1   1079    0   43   66.77075     0     0      0     100       0    1  ...
# 2    492    1   34   82.91725     0     0      0      90       0    1  ...
# 3   1191    1   41   98.91817     0     0      0      81       0    1  ...
# 4   1141    3   47   53.61717     0     1      0     100       0    0  ...
# 5   1071    2   20   62.11097     0     0      0      82       0    1  ...
# 6    587    2   25   63.88170     1     1      0     100       0    1  ...
# 7   1145    2   30   75.75620     0     1      0      90       0    1  ...
# 8   1047    3   30   89.61961     0     1      0     100       0    0  ...
# 9    481    3   40   79.16276     0     1      0     100       0    0  ...
# 10  1072    0   26  103.29022     0     0      0     100       0    1  ...
# 11  1079    1   36   59.72029     0     0      0      90       0    1  ...
# 12   397    3   34   95.52883     0     1      0      90       0    1  ...
# 13   525    0   29   83.78999     0     1      0     100       0    1  ...
# 14   965    0   27   86.52589     0     1      0     100       0    1  ...
# 15  1142    3   33   85.44977     0     1      0     100       0    0  ...
# 16   581    0   47   67.43588     0     1      0     100       0    1  ...
# 17  1114    2   29   81.25844     0     1      0      90       0    1  ...
# 18  1127    1   34   85.41241     0     0      0     100       1    1  ...
# 19   291    3   42   92.41593     0     1      0     100       0    1  ...
# 20  1157    2   46   73.68461     0     1      0     100       0    1  ...
# 21   851    1   29   72.15169     0     1      1     100       0    1  ...
# 22  1028    0   35   79.99706     0     0      0     100       0    1  ...
# 23  1120    0   33   64.55049     0     1      0     100       0    0  ...
# 24   462    0   45   70.77242     0     1      0     100       0    1  ...
# 25   519    3   23   69.57535     0     1      0     100       0    1  ...
# 26  1138    3   31   75.33223     0     1      0     100       0    1  ...
# 27  1171    3   39   69.90289     0     1      0     100       0    0  ...
# 28   498    2   42   70.27584     0     1      0     100       0    1  ...
# 29  1038    1   33   81.93435     0     1      0     100       0    0  ...
#
#     str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  cd820  infected
# 0      1      1        0      0       0   389    320   734    737         1
# 1      0      2        0      1       1   318    432   912   1213         0
# 2      1      2        0      1       1   326    524   660    835         0
# 3      1      3        0      1       0   318    232  1131    982         1
# 4      0      1        0      1       0   280    337   515    679         0
# 5      1      1        0      0       0   257    218  1249   1546         0
# 6      1      2        0      1       1   199    555  1065   1219         1
# 7      1      2        0      1       1   480    330   830    921         0
# 8      0      1        0      1       0   223    627   663    630         0
# 9      1      3        1      0       0   202    177   563   1301         0
# 10     0      3        0      1       0   432    425  1038    687         0
# 11     0      1        0      1       1   243    681   872    502         0
# 12     1      3        0      1       1   428    331   598   1783         0
# 13     1      2        0      1       0   454    376  1792   1001         0
# 14     1      3        1      0       0   202    224   641    880         1
# 15     0      1        0      1       0   477    526   713    539         0
# 16     1      1        0      1       0   171    346  1290    978         0
# 17     1      3        0      1       1   209    321   882    753         1
# 18     1      3        0      1       0   312    132   819    886         1
# 19     1      2        0      1       1   253    483  1237   1048         1
# 20     1      3        0      1       0   191    259  1154   1159         0
# 21     1      2        1      0       1   349    520   557    822         0
# 22     0      1        0      1       0   234    631  1727    704         0
# 23     0      1        0      0       0   374    633  1001   1220         0
# 24     1      2        0      1       0   153    514   474    754         1
# 25     0      1        0      0       1   308    352  1457    467         0
# 26     1      1        0      1       0   282    419   750    611         0
# 27     0      1        0      1       0   173    314  1225    919         0
# 28     1      3        0      0       1   282    553   903   1076         0
# 29     1      1        0      0       0   193    571  1582   1704         0
#
# [30 rows x 23 columns]

# %%
df.dropna()
# Out:
#        time  trt  age       wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  \
# 0      1108    1   37   88.11364     0     1      1     100       0    1  ...
# 1      1079    0   43   66.77075     0     0      0     100       0    1  ...
# 2       492    1   34   82.91725     0     0      0      90       0    1  ...
# 3      1191    1   41   98.91817     0     0      0      81       0    1  ...
# 4      1141    3   47   53.61717     0     1      0     100       0    0  ...
# ...     ...  ...  ...        ...   ...   ...    ...     ...     ...  ...  ...
# 14995  1162    3   36   59.63057     0     1      0     100       0    0  ...
# 14996  1158    0   27  102.69575     0     0      0      90       0    0  ...
# 14997   468    3   40   79.07121     0     1      1      90       0    1  ...
# 14998  1194    2   40   80.51779     0     0      0      90       0    0  ...
# 14999   582    3   31   65.35591     0     1      0      90       0    1  ...
#
#        str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  cd820  infected
# 0         1      1        0      0       0   389    320   734    737         1
# 1         0      2        0      1       1   318    432   912   1213         0
# 2         1      2        0      1       1   326    524   660    835         0
# 3         1      3        0      1       0   318    232  1131    982         1
# 4         0      1        0      1       0   280    337   515    679         0
# ...     ...    ...      ...    ...     ...   ...    ...   ...    ...       ...
# 14995     0      1        0      1       1   263    358  2091    608         0
# 14996     0      1        0      1       0   327    582   839    392         0
# 14997     1      3        0      1       0   283    211  2325   1000         1
# 14998     1      3        1      1       0   237    406   560    860         0
# 14999     1      3        0      1       0   248    525  1547   1223         1
#
# [15000 rows x 23 columns]

# %%
df[(df['wtkg']>=75.56)]
# Out:
#        time  trt  age       wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  \
# 0      1108    1   37   88.11364     0     1      1     100       0    1  ...
# 2       492    1   34   82.91725     0     0      0      90       0    1  ...
# 3      1191    1   41   98.91817     0     0      0      81       0    1  ...
# 7      1145    2   30   75.75620     0     1      0      90       0    1  ...
# 8      1047    3   30   89.61961     0     1      0     100       0    0  ...
# ...     ...  ...  ...        ...   ...   ...    ...     ...     ...  ...  ...
# 14992   551    1   36   83.75366     0     0      0     100       0    0  ...
# 14993  1116    3   32   77.83044     0     0      0      90       0    1  ...
# 14996  1158    0   27  102.69575     0     0      0      90       0    0  ...
# 14997   468    3   40   79.07121     0     1      1      90       0    1  ...
# 14998  1194    2   40   80.51779     0     0      0      90       0    0  ...
#
#        str2  strat  symptom  treat  offtrt  cd40  cd420  cd80  cd820  infected
# 0         1      1        0      0       0   389    320   734    737         1
# 2         1      2        0      1       1   326    524   660    835         0
# 3         1      3        0      1       0   318    232  1131    982         1
# 7         1      2        0      1       1   480    330   830    921         0
# 8         0      1        0      1       0   223    627   663    630         0
# ...     ...    ...      ...    ...     ...   ...    ...   ...    ...       ...
# 14992     0      1        0      1       1   400    393   781   1075         0
# 14993     1      2        0      1       1   285    268   905    564         0
# 14996     0      1        0      1       0   327    582   839    392         0
# 14997     1      3        0      1       0   283    211  2325   1000         1
# 14998     1      3        1      1       0   237    406   560    860         0
#
# [6610 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
X = df.drop("infected",axis=1)
Y = df["infected"]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
df.dropna(inplace = True)

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [0 0 0 ... 0 1 0]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6886666666666666

# %%
res = accuracy_score(Y_test,y_pred)

# %%
from sklearn.svm import SVC

# %%
model1 = SVC()

# %%
model1.fit(X_train,Y_train)
# Out:
# SVC()

# %%
y_pred1 = model1.predict(X_test)

# %%
print(y_pred1)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy1 = accuracy_score(Y_test,y_pred1)

# %%
print("Accuracy :- ", accuracy1*100)
# Out:
# Accuracy :-  67.23333333333333

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model2 = KNeighborsClassifier()

# %%
model2.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred2 = model2.predict(X_test)

# %%
accuracy2 = accuracy_score(y_pred2,Y_test)

# %%
print("KNN-Accuracy:- ",accuracy*100)
# Out:
# KNN-Accuracy:-  68.86666666666666

# %%
 from sklearn.ensemble import RandomForestClassifier
 from sklearn.ensemble import VotingClassifier

# %%
vc = VotingClassifier(estimators=[('logistic',model),('svm',model1),('KNN',model2)],voting='hard')

# %%
vc.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# VotingClassifier(estimators=[('logistic', LogisticRegression()), ('svm', SVC()),
#                              ('KNN', KNeighborsClassifier())])

# %%
vp = vc.predict(X_test)

# %%
vacc = accuracy_score(Y_test,vp)

# %%
print(vacc*100)
# Out:
# 68.43333333333334
