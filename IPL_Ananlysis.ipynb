# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Book_ipl22_ver_33.csv')
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
df[(df['highscore']>70)]
# Out:
#     match_id           date                                         venue  \
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 8          9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9         10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
# 14        15   April 7,2022            Dr DY Patil Sports Academy, Mumbai
# 15        16   April 8,2022                     Brabourne Stadium, Mumbai
# 16        17   April 9,2022            Dr DY Patil Sports Academy, Mumbai
# 21        22  April 12,2022            Dr DY Patil Sports Academy, Mumbai
# 23        24  April 14,2022            Dr DY Patil Sports Academy, Mumbai
# 24        25  April 15,2022                     Brabourne Stadium, Mumbai
# 25        26  April 16,2022                     Brabourne Stadium, Mumbai
# 28        29  April 17,2022  Maharashtra Cricket Association Stadium,Pune
# ...

# %%
df[(df['match_winner']=='Delhi')]
# Out:
#     match_id           date                               venue  team1  \
# 1          2  March 27,2022           Brabourne Stadium, Mumbai  Delhi
# 18        19  April 10,2022           Brabourne Stadium, Mumbai  Delhi
# 31        32  April 20,2022           Brabourne Stadium, Mumbai  Delhi
# 40        41  April 28,2022            Wankhede Stadium, Mumbai  Delhi
# 49        50     May 5,2022           Brabourne Stadium, Mumbai  Delhi
# 57        58    May 11,2022  Dr DY Patil Sports Academy, Mumbai  Delhi
# 63        64    May 16,2022  Dr DY Patil Sports Academy, Mumbai  Delhi
#
#         team2  stage toss_winner toss_decision  first_ings_score  \
# 1      Mumbai  Group       Delhi         Field               177
# 18    Kolkata  Group     Kolkata         Field               215
# 31     Punjab  Group       Delhi         Field               115
# 40    Kolkata  Group       Delhi         Field               146
# 49  Hyderabad  Group   Hyderabad         Field               207
# ...

# %%
df[(df['won_by']=='Wickets')]
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 5          6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6          7  March 31,2022                     Brabourne Stadium, Mumbai
# 7          8   April 1,2022                      Wankhede Stadium, Mumbai
# 12        13   April 5,2022                      Wankhede Stadium, Mumbai
# 13        14   April 6,2022  Maharashtra Cricket Association Stadium,Pune
# 14        15   April 7,2022            Dr DY Patil Sports Academy, Mumbai
# 15        16   April 8,2022                     Brabourne Stadium, Mumbai
# 16        17   April 9,2022            Dr DY Patil Sports Academy, Mumbai
# ...

# %%
df[(df['player_of_the_match']=='Kuldeep Yadav') | (df['player_of_the_match']=='David Warner')]
# Out:
#     match_id           date                      venue  team1      team2  \
# 1          2  March 27,2022  Brabourne Stadium, Mumbai  Delhi     Mumbai
# 18        19  April 10,2022  Brabourne Stadium, Mumbai  Delhi    Kolkata
# 31        32  April 20,2022  Brabourne Stadium, Mumbai  Delhi     Punjab
# 40        41  April 28,2022   Wankhede Stadium, Mumbai  Delhi    Kolkata
# 49        50     May 5,2022  Brabourne Stadium, Mumbai  Delhi  Hyderabad
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 1   Group       Delhi         Field               177                5
# 18  Group     Kolkata         Field               215                5
# 31  Group       Delhi         Field               115               10
# 40  Group       Delhi         Field               146                9
# 49  Group   Hyderabad         Field               207                3
#
#     second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# ...

# %%
df[(df['toss_winner']=='Kolkata')]
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 7          8   April 1,2022                      Wankhede Stadium, Mumbai
# 13        14   April 6,2022  Maharashtra Cricket Association Stadium,Pune
# 18        19  April 10,2022                     Brabourne Stadium, Mumbai
# 29        30  April 18,2022                     Brabourne Stadium, Mumbai
# 46        47     May 2,2022                      Wankhede Stadium, Mumbai
# 52        53     May 7,2022  Maharashtra Cricket Association Stadium,Pune
# 60        61    May 14,2022  Maharashtra Cricket Association Stadium,Pune
#
#         team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0     Chennai    Kolkata  Group     Kolkata         Field               131
# 7     Kolkata     Punjab  Group     Kolkata         Field               137
# ...

# %%
df[(df['team1']=='Chennai') & (df['team2']=='Kolkata')]
# Out:
#    match_id           date                     venue    team1    team2  stage  \
# 0         1  March 26,2022  Wankhede Stadium, Mumbai  Chennai  Kolkata  Group
#
#   toss_winner toss_decision  first_ings_score  first_ings_wkts  \
# 0     Kolkata         Field               131                5
#
#    second_ings_score  second_ings_wkts match_winner   won_by  margin  \
# 0                133                 4      Kolkata  Wickets       6
#
#   player_of_the_match top_scorer  highscore  best_bowling best_bowling_figure
# 0         Umesh Yadav   MS Dhoni         50  Dwayne Bravo               3--20

# %%
len(df[(df["player_of_the_match"] == "Hardik Pandya")])
# Out:
# 2
