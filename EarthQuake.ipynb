# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/earthquake_1995-2023.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1000 non-null   object
#  1   magnitude  1000 non-null   float64
#  2   date_time  1000 non-null   object
#  3   cdi        1000 non-null   int64
#  4   mmi        1000 non-null   int64
#  5   alert      449 non-null    object
#  6   tsunami    1000 non-null   int64
#  7   sig        1000 non-null   int64
#  8   net        1000 non-null   object
#  9   nst        1000 non-null   int64
#  10  dmin       1000 non-null   float64
#  11  gap        1000 non-null   float64
#  12  magType    1000 non-null   object
#  13  depth      1000 non-null   float64
#  14  latitude   1000 non-null   float64
#  15  longitude  1000 non-null   float64
#  16  location   994 non-null    object
#  17  continent  284 non-null    object
#  18  country    651 non-null    object
# ...

# %%
df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
# ...

# %%
df.tail(5)
# Out:
#                                          title  magnitude         date_time  \
# 995          M 7.1 - 85 km S of Tungor, Russia        7.1  27-05-1995 13:03
# 996     M 7.7 - 249 km E of Vao, New Caledonia        7.7  16-05-1995 20:12
# 997  M 6.9 - 27 km NNW of Maubara, Timor Leste        6.9  14-05-1995 11:33
# 998           M 6.6 - 10 km W of Aianí, Greece        6.6  13-05-1995 08:47
# 999  M 7.1 - 14 km NE of Cabatuan, Philippines        7.1  05-05-1995 03:53
#
#      cdi  mmi alert  tsunami  sig net  nst  dmin  gap magType  depth  \
# 995    0    9   NaN        0  776  us    0   0.0  0.0     mwb   11.0
# 996    0    4   NaN        0  912  us    0   0.0  0.0      mw   20.2
# 997    0    6   NaN        0  732  us    0   0.0  0.0      mw   11.2
# 998    0    9   NaN        0  670  us    0   0.0  0.0      mw   14.0
# 999    0    7   NaN        0  776  us    0   0.0  0.0      mw   16.0
#
#      latitude  longitude               location continent      country
# ...

# %%
df[(df['date_time']>'27-01-1995')]
# Out:
#                                               title  magnitude  \
# 12                M 6.6 - south of the Fiji Islands        6.6
# 51          M 7.0 - 11 km NE of Bantay, Philippines        7.0
# 57         M 7.0 - southeast of the Loyalty Islands        7.0
# 58      M 6.9 - 284 km ESE of Tadine, New Caledonia        6.9
# 65                  M 6.5 - Kermadec Islands region        6.5
# ..                                              ...        ...
# 956  M 7.2 - 58 km WSW of Panguna, Papua New Guinea        7.2
# 985           M 6.6 - 95 km SW of Etchoropo, Mexico        6.6
# 991         M 8.0 - 36 km NNE of Antofagasta, Chile        8.0
# 993            M 6.6 - 0 km ESE of Isangel, Vanuatu        6.6
# 995               M 7.1 - 85 km S of Tungor, Russia        7.1
#
#             date_time  cdi  mmi   alert  tsunami   sig net  nst   dmin   gap  \
# 12   28-04-2023 03:13    0    2   green        0   670  us   52  5.123  50.0
# ...

# %%
df[(df['magnitude']>=5.5)]
# Out:
#                                          title  magnitude         date_time  \
# 0             M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47
# 1     M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22
# 2     M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05
# 3        M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48
# 4                     M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48
# ..                                         ...        ...               ...
# 995          M 7.1 - 85 km S of Tungor, Russia        7.1  27-05-1995 13:03
# 996     M 7.7 - 249 km E of Vao, New Caledonia        7.7  16-05-1995 20:12
# 997  M 6.9 - 27 km NNW of Maubara, Timor Leste        6.9  14-05-1995 11:33
# 998           M 6.6 - 10 km W of Aianí, Greece        6.6  13-05-1995 08:47
# 999  M 7.1 - 14 km NE of Cabatuan, Philippines        7.1  05-05-1995 03:53
#
# ...

# %%
df[(df['country']=='Russia')]
# Out:
#                                                  title  magnitude  \
# 141              M 7.0 - 95 km ENE of Kuril’sk, Russia        7.0
# 248  M 6.6 - 81 km NNE of Ust’-Kamchatsk Staryy, Ru...        6.6
# 293                M 7.2 - 80 km S of Mil’kovo, Russia        7.2
# 433             M 7.2 - 252 km ENE of Kuril’sk, Russia        7.2
# 441           M 6.6 - 183 km SW of Belaya Gora, Russia        6.6
# 480              M 6.7 - 38 km NE of Saryg-Sep, Russia        6.7
# 484             M 6.6 - 45 km NNE of Saryg-Sep, Russia        6.6
# 656           M 6.5 - 81 km ESE of Ozernovskiy, Russia        6.5
# 660             M 6.6 - 42 km NNW of Tilichiki, Russia        6.6
# 666               M 6.6 - 80 km E of Tilichiki, Russia        6.6
# 667              M 7.6 - 80 km NE of Tilichiki, Russia        7.6
# 724              M 6.9 - 24 km ENE of Atlasovo, Russia        6.9
# 743                   M 6.7 - 9 km S of Aktash, Russia        6.7
# ...

# %%
X = df.drop("tsunami",axis=1)
Y = df["tsunami"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_train = train_test_split(X,Y,train_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model =LinearRegression()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-ffa49499a3bf> in <cell line: 1>()
# ----> 1 model.fit(X_train,Y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...
