# %%
import pandas as pd
df = pd.read_csv('/pokemon_data.csv')
# print(df)
# print(df.columns)
# print(df['Name'])
# print(df.Name)
# print(df.Name,5)
# print(df.head)
# print(df.head)
#df.to_csv('modified.csv',index = False)
#df.to_excel('modofied.xlsx',index = False)
# df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') &(df['HP']>70) & (df['Speed']>75)]
# df.to_excel('modofied.xlsx',index = False)

# df = pd.read_csv('modified.csv')
# df['count'] = 1
# df.groupby(['Type 1']).count()['count']
df.groupby(['Type 1'],['Type2'].count()['count'])

# %%
import pandas as pd
df = pd.read_csv('/content/pokemon_data.csv')
# print(df)
# print(df.columns)
# print(df.Name)
# print(df['Name'])
print(df.Name,5)
print(df.head)
df.to_csv('modified.csv',index = False)
print(df.Attack)
df.loc[(df['Type 1'] == 'Grass') &(df['Speed']>60)]
df.loc[(df['Type 2'] == 'Poison') & (df['Type 2']== 'Flying')]
df.loc[(df['Speed']>100) & (df['Defense']>=70)]
df.loc[(df['Legendary']=='False')]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object 5
# <bound method NDFrame.head of        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# ...

# %%
import pandas as pd

var = {"day1":110,"day2":200,"day3":250}

# Fix the function call
series = pd.Series(var)

# Print the series
print(series)
# Out:
# day1    110
# day2    200
# day3    250
# dtype: int64
